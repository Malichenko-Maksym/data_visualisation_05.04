# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
winChart= pd.Series([24,22,20,14], index=['Novak Djokovic','Rafael Nadal','Roger Federer','Pete Sampras'])
winChart.plot(kind='bar', title='Grand Slam tournament winners', xlabel='Name of player', ylabel='titles')
# Out:
# <Axes: title={'center': 'Grand Slam tournament winners'}, xlabel='Name of player', ylabel='titles'>
